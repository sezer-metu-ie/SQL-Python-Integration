# %%
import pyodbc 

try:
    # Bağlantı dizesi
    conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=.\\SQLEXPRESS01;'
                          'Database=master;'
                          'Trusted_Connection=yes;')
    
    print("Bağlantı Başarılı! Python artık SQL ile konuşabiliyor.")
    
except Exception as e:
    print("Bağlantı kurulamadı, hata şu: ", e)
# Out:
# Bağlantı Başarılı! Python artık SQL ile konuşabiliyor.
